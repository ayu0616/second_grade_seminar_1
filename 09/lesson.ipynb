# %%
install.packages("languageserver")
# Out:
# The downloaded binary packages are in
# 	/var/folders/4x/vf52k2q52wx0sqrm0t5hfr040000gn/T//Rtmp9AwCxb/downloaded_packages

# %%
install.packages("kohonen")
# Out:
# The downloaded binary packages are in
# 	/var/folders/4x/vf52k2q52wx0sqrm0t5hfr040000gn/T//Rtmp9AwCxb/downloaded_packages

# %%
library("kohonen")

# %%
set.seed(10)

# %%
gr <- somgrid(topo = "hexagonal", xdim = 10, ydim = 7)

# %%
iris.som <- som(as.matrix(iris[, 1:4]), gr, rlen = 200) # nolint

# %%
plot(iris.som, type = "codes")
# Out:
# plot without title

# %%
lab.cod <- as.numeric(iris[, 5]) # nolint
plot(iris.som, type = "mapping", labels = lab.cod, col = lab.cod)
# Out:
# plot without title

# %%
plot(iris.som, type = "change")
# Out:
# Plot with title “Training progress”

# %%
plot(cars)
# Out:
# plot without title

# %%
cor(cars)
# Out:
#       speed     dist
# speed 1.0000000 0.8068949
# dist  0.8068949 1.0000000

# %%
# lm(目的変数~説明変数, **args)
cars.lm <- lm(dist ~ speed, data = cars)

# %%
summary(cars.lm)
# Out:
# Call:
# lm(formula = dist ~ speed, data = cars)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -29.069  -9.525  -2.272   9.215  43.201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -17.5791     6.7584  -2.601   0.0123 *
# speed         3.9324     0.4155   9.464 1.49e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.38 on 48 degrees of freedom
# Multiple R-squared:  0.6511,	Adjusted R-squared:  0.6438
# F-statistic: 89.57 on 1 and 48 DF,  p-value: 1.49e-12

# %%
residuals(cars.lm)
# Out:
#          1          2          3          4          5          6          7
#   3.849460  11.849460  -5.947766  12.052234   2.119825  -7.812584  -3.744993
#          8          9         10         11         12         13         14
#   4.255007  12.255007  -8.677401   2.322599 -15.609810  -9.609810  -5.609810
#         15         16         17         18         19         20         21
#  -1.609810  -7.542219   0.457781   0.457781  12.457781 -11.474628  -1.474628
#         22         23         24         25         26         27         28
#  22.525372  42.525372 -21.407036 -15.407036  12.592964 -13.339445  -5.339445
#         29         30         31         32         33         34         35
# -17.271854  -9.271854   0.728146 -11.204263   2.795737  22.795737  30.795737
#         36         37         38         39         40         41         42
# -21.136672 -11.136672  10.863328 -29.069080 -13.069080  -9.069080  -5.069080
# ...

# %%
plot(cars)
abline(cars.lm, lwd = 2)
# Out:
# plot without title

# %%
z = data.frame(speed = c(1, 3, 5))

# %%
predict(cars.lm, z)
# Out:
#          1          2          3
# -13.646686  -5.781869   2.082949
