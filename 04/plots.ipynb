# %%
hist(iris[1:50, 2])
# Out:
# Plot with title “Histogram of iris[1:50, 2]”

# %%
z = hist(iris[1:50, 2])
z
# Out:
# $breaks
# [1] 2.0 2.5 3.0 3.5 4.0 4.5
#
# $counts
# [1]  1  7 26 13  3
#
# $density
# [1] 0.04 0.28 1.04 0.52 0.12
#
# $mids
# [1] 2.25 2.75 3.25 3.75 4.25
#
# $xname
# [1] "iris[1:50, 2]"
#
# $equidist
# [1] TRUE
#
# attr(,"class")
# [1] "histogram"
# Plot with title “Histogram of iris[1:50, 2]”

# %%
hist(iris[1:50, 2], col = c("lightblue", "lightgreen"))
# Out:
# Plot with title “Histogram of iris[1:50, 2]”

# %%
hist(iris[1:50, 2], col = c("lightblue", "lightgreen"), breaks = c(1:5))
# Out:
# Plot with title “Histogram of iris[1:50, 2]”

# %%
matplot(VADeaths, type = "b")
# Out:
# plot without title

# %%
boxplot(iris[,1:4])
# Out:
# plot without title

# %%
boxplot(iris[,c(2, 4)])
# Out:
# plot without title

# %%
boxplot(iris[,1]~iris[,5])
# Out:
# plot without title

# %%
plot(iris[, 1:2])
# Out:
# plot without title

# %%
plot(iris)
# Out:
# plot without title
