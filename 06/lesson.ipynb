# %%
library(MASS)

# %%
help(caith)
# Out:
# caith                   package:MASS                   R Documentation
#
# s
#
# n:
#
#      Data on the cross-classification of people in Caithness, Scotland,
#      by eye and hair colour. The region of the UK is particularly
#      interesting as there is a mixture of people of Nordic, Celtic and
#      Anglo-Saxon origin.
#
# e:
#
#      caith
#
# t:
#
#      A 4 by 5 table with rows the eye colours (blue, light, medium,
#      dark) and columns the hair colours (fair, red, medium, dark,
#      black).
#
# e:
#
#      Fisher, R.A. (1940) The precision of discriminant functions.
#      _Annals of Eugenics (London)_ *10*, 422-429.
#
# s:
#
#      Venables, W. N. and Ripley, B. D. (2002) _Modern Applied
#      Statistics with S._ Fourth edition.  Springer.
#
# s:
#
#      corresp(caith)
#      dimnames(caith)[[2]] <- c("F", "R", "M", "D", "B")
#      par(mfcol=c(1,3))
#      plot(corresp(caith, nf=2)); title("symmetric")
#      plot(corresp(caith, nf=2), type="rows"); title("rows")
# ...

# %%
caith
# Out:
#        fair red medium dark black
# blue   326   38 241    110   3
# light  688  116 584    188   4
# medium 343   84 909    412  26
# dark    98   48 403    681  85

# %%
caith.ca = corresp(caith, nf = 4)

# %%
plot(caith.ca$rscore[, 1:2], type="n")
text(caith.ca$rscore)
# Out:
# plot without title

# %%
plot(caith.ca$cscore[, 1:2], type="n")
text(caith.ca$cscore)
# Out:
# plot without title

# %%
biplot(caith.ca)
# Out:
# plot without title

# %%
itemA = c("A1","A1","A1","A1","A1","A2","A2","A2","A2","A2")
itemB = c("B1","B2","B3","B1","B1","B2","B2","B1","B3","B2")
itemC = c("C2","C3","C1","C3","C2","C1","C3","C1","C1","C2")
itemA = data.frame(factor(itemA))
itemB = data.frame(factor(itemB))
itemC = data.frame(factor(itemC))
hyou2 = cbind(itemA,itemB,itemC)

# %%
hyou2
# Out:
#    factor.itemA. factor.itemB. factor.itemC.
# 1  A1            B1            C2
# 2  A1            B2            C3
# 3  A1            B3            C1
# 4  A1            B1            C3
# 5  A1            B1            C2
# 6  A2            B2            C1
# 7  A2            B2            C3
# 8  A2            B1            C1
# 9  A2            B3            C1
# 10 A2            B2            C2

# %%
hyou2.mca = mca(hyou2)

# %%
biplot(hyou2.mca$rs, hyou2.mca$cs, var.axes = FALSE)
# Out:
# plot without title
